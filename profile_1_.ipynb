# %%
import pandas as pd
df = pd.read_csv('profile1.csv')

# %%
df
# Out:
#     id_          nickname  age          status sex orientation body_type  \
# 0     0           Miranda   21          single   f    straight   No info
# 1     1               Ken   22       available   m    straight   No info
# 2     2    Beebeep Bajeep   25       available   m    straight   No info
# 3     3             puppy   26          single   m    bisexual   No info
# 4     4              Samu   27          single   m    bisexual   No info
# 5     5             Wayne   27  seeing someone   m    bisexual   No info
# 6     6               Tom   27  seeing someone   m    straight   No info
# 7     7  George Timberman   31          single   m    straight   No info
# 8     8         Fox Creek   31  seeing someone   m    straight   No info
# 9     9              doge   32         married   m    straight   No info
# 10   10            Roonie   37         married   f    straight   No info
# 11   11              Toby   40         married   m    straight   No info
# ...

# %%
df.headshot_url=df.headshot_url.str.replace(r'"','')

# %%
df
# Out:
#     id_          nickname  age          status sex orientation body_type  \
# 0     0           Miranda   21          single   f    straight   No info
# 1     1               Ken   22       available   m    straight   No info
# 2     2    Beebeep Bajeep   25       available   m    straight   No info
# 3     3             puppy   26          single   m    bisexual   No info
# 4     4              Samu   27          single   m    bisexual   No info
# 5     5             Wayne   27  seeing someone   m    bisexual   No info
# 6     6               Tom   27  seeing someone   m    straight   No info
# 7     7  George Timberman   31          single   m    straight   No info
# 8     8         Fox Creek   31  seeing someone   m    straight   No info
# 9     9              doge   32         married   m    straight   No info
# 10   10            Roonie   37         married   f    straight   No info
# 11   11              Toby   40         married   m    straight   No info
# ...

# %%
player_filter = df.loc[(df['nickname'] == 'Miranda')]

# %%
url
# Out:
# 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5209176-035clefairy.png'

# %%
feed = pd.Series(df.headshot_url.values,index=df.nickname).to_dict()

# %%
feed
# Out:
# {'Miranda': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5209176-035clefairy.png',
#  'Ken': 'https://comicvine1.cbsistatic.com/uploads/original/6/63099/1998241-ep067.png',
#  'Beebeep Bajeep': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5198759-068machamp.png',
#  'puppy': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5198898-003venusaur-mega.png',
#  'Samu': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5213189-042golbat.png',
#  'Wayne': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5198880-007squirtle.png',
#  'Tom': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/4357615-250px-094gengar.png',
#  'George Timberman': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5215180-175togepi.png',
#  'Fox Creek': 'https://comicvine1.cbsistatic.com/uploads/original/11/114183/5198871-143snorlax.png',
# ...

# %%
st.subheader('About me')
st.image(url, width=300)
